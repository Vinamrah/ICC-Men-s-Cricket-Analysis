# %%
# importing all the necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# user header - identify the client making the request, ensuring compatibility and sometimes avoiding blocks by the server.
import requests
from bs4 import BeautifulSoup

url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;orderby=wickets;spanmax1=31+May+2024;spanmin1=01+Jan+1990;spanval1=span;template=results;type=bowling"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    # Your scraping logic
else:
    print(f"Failed to retrieve content: {response.status_code}")

# %%
content = soup.find_all("tr",class_='data1')
print(len(content))
# Out:
# 50

# %%
for i in content:
    # print(i) 
    player = i.find_all('td')
    # print(player)
    players_info = []
    for j in player:
        if(j.text!=''):
           # print(j.text)
            players_info.append(j.text)
    break

# %%
players_info
# Out:
# ['TG Southee (NZ)',
#  '2008-2024',
#  '123',
#  '120',
#  '446.5',
#  '6',
#  '3635',
#  '157',
#  '5/18',
#  '23.15',
#  '8.13',
#  '17.0',
#  '2',
#  '2']

# %%
# Finally scraping information from pages 1 to 78

# Initialize the final list to store players' information
final_players_list = []

# Loop through pages 1 to 78
for i in range(1, 79):
    url = f"https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page={i};spanmax2=31+May+2024;spanmin2=01+Jan+1990;spanval2=span;template=results;type=bowling"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Will raise an HTTPError for bad responses
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve content from page {i}: {e}")
        continue

    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.find_all("tr", class_='data1')

    for k in content:
        player = k.find_all('td')
        players_info = [j.text.strip() for j in player if j.text.strip()]
        if players_info:
            final_players_list.append(players_info)

print(final_players_list)
# Out:
# [['TG Southee (NZ)', '2008-2024', '123', '120', '446.5', '6', '3635', '157', '5/18', '23.15', '8.13', '17.0', '2', '2'], ['Shakib Al Hasan (BAN)', '2006-2024', '122', '120', '440.1', '3', '2987', '146', '5/20', '20.45', '6.78', '18.0', '6', '2'], ['Rashid Khan (AFG/ICC)', '2015-2024', '85', '85', '324.2', '1', '1970', '138', '5/3', '14.27', '6.07', '14.1', '5', '2'], ['IS Sodhi (NZ)', '2014-2024', '116', '111', '392.5', '0', '3142', '136', '4/28', '23.10', '7.99', '17.3', '3', '0'], ['Mustafizur Rahman (BAN)', '2015-2024', '96', '95', '342.4', '7', '2588', '120', '6/10', '21.56', '7.55', '17.1', '3', '2'], ['MR Adair (IRE)', '2019-2024', '83', '83', '296.4', '2', '2301', '119', '4/13', '19.33', '7.75', '14.9', '3', '0'], ['MJ Santner (NZ)', '2015-2024', '100', '98', '345.2', '2', '2457', '111', '4/11', '22.13', '7.11', '18.6', '3', '0'], ['AU Rashid (ENG)', '2009-2024', '106', '102', '372.2', '4', '2750', '110', '4/2', '25.00', '7.38', '20.3', '2', '0'], ['SL Malinga (SL)', '2006-2020', '84', '83', '299.5', '1', '2225', '107', '5/6', '20.79', '7.42', '16.8', '1', '2'], ['Shadab Khan (PAK)', '2017-2024', '100', '94', '344.1', '3', '2484', '107', '4/8', '23.21', '7.21', '19.2', '3', '0'], ['Bilal Khan (OMA)', '2015-2024', '75', '74', '270.5', '7', '1810', '106', '4/19', '17.07', '6.68', '15.3', '3', '0'], ['PW Hasaranga (SL)', '2019-2024', '65', '63', '236.4', '1', '1619', '104', '4/9', '15.56', '6.84', '13.6', '3', '0'], ['SO Ngoche (KENYA)', '2010-2024', '84', '82', '282.4', '12', '1706', '99', '4/14', '17.23', '6.03', '17.1', '3', '0'], ['CJ Jordan (ENG)', '2014-2024', '90', '89', '311.4', '2', '2713', '98', '4/6', '27.68', '8.70', '19.0', '3', '0'], ['S Lamichhane (ICC/NEP)', '2018-2023', '52', '52', '195.5', '5', '1233', '98', '5/9', '12.58', '6.29', '11.9', '2', '1'], ['Shahid Afridi (ICC/PAK)', '2006-2018', '99', '97', '361.2', '4', '2396', '98', '4/11', '24.44', '6.63', '22.1', '3', '0'], ['YS Chahal (IND)', '2016-2023', '80', '79', '294.0', '2', '2409', '96', '6/25', '25.09', '8.19', '18.3', '2', '1'], ['Haris Rauf (PAK)', '2020-2024', '68', '66', '246.4', '1', '2035', '95', '4/18', '21.42', '8.25', '15.5', '3', '0'], ['H Ssenyondo (UGA)', '2019-2024', '77', '73', '254.4', '8', '1371', '94', '4/4', '14.58', '5.38', '16.2', '7', '0'], ['Mohammad Nabi (AFG)', '2010-2024', '121', '113', '355.4', '5', '2616', '93', '4/10', '28.12', '7.35', '22.9', '3', '0'], ['A Zampa (AUS)', '2016-2024', '80', '79', '285.5', '1', '2082', '92', '5/19', '22.63', '7.28', '18.6', '1', '1'], ['Ehsan Khan (HKG)', '2016-2024', '67', '66', '247.0', '4', '1522', '91', '4/24', '16.72', '6.16', '16.2', '2', '0'], ['Shaheen Shah Afridi (PAK)', '2018-2024', '66', '66', '239.4', '2', '1853', '91', '4/22', '20.36', '7.73', '15.8', '2', '0'], ['Aizaz Khan (HKG)', '2014-2024', '77', '74', '240.1', '4', '1860', '90', '4/26', '20.66', '7.74', '16.0', '2', '0'], ['Karan KC (NEP)', '2015-2024', '68', '68', '221.0', '6', '1729', '90', '5/21', '19.21', '7.82', '14.7', '3', '1'], ['B Kumar (IND)', '2012-2022', '87', '86', '298.3', '10', '2079', '90', '5/4', '23.10', '6.96', '19.9', '3', '2'], ['Saeed Ajmal (PAK)', '2009-2015', '64', '63', '238.2', '2', '1516', '85', '4/19', '17.83', '6.36', '16.8', '4', '0'], ['Umar Gul (PAK)', '2007-2016', '60', '60', '200.3', '2', '1443', '85', '5/6', '16.97', '7.19', '14.1', '4', '2'], ['GH Dockrell (IRE)', '2010-2024', '136', '93', '266.2', '1', '1905', '83', '4/20', '22.95', '7.15', '19.2', '1', '0'], ['DJ Bravo (WI)', '2006-2021', '91', '77', '250.5', '0', '2036', '78', '4/19', '26.10', '8.11', '19.2', '3', '0'], ['JB Little (IRE)', '2016-2024', '66', '65', '243.2', '2', '1814', '78', '4/23', '23.25', '7.45', '18.7', '2', '0'], ['T Shamsi (SA)', '2017-2023', '65', '65', '234.4', '1', '1732', '78', '5/24', '22.20', '7.38', '18.0', '2', '1'], ['MRJ Watt (SCOT)', '2015-2024', '63', '61', '221.1', '4', '1507', '77', '5/27', '19.57', '6.81', '17.2', '2', '1'], ['A Bohara (NEP)', '2019-2024', '59', '56', '194.0', '2', '1420', '74 ...

# %%
field = ['name','span','matches','innings','overs','maiden_overs','runs_conceded','wickets','best_bowling_figure','average','economy_rate','bowling_strike_rate','four_wickets_haul','five_wickets_haul']

# %%
import csv
with open("T20I_bowling_record.csv",'w') as f:
    csvwriter= csv.writer(f)
    csvwriter.writerow(field)
    csvwriter.writerows(final_players_list)
    
f.close()

# %%
df = pd.read_csv('T20I_bowling_record.csv')

# %%
df.shape
# Out:
# (3872, 14)
