# %%
# importing all the necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# user header - identify the client making the request, ensuring compatibility and sometimes avoiding blocks by the server.
import requests
from bs4 import BeautifulSoup

url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;spanmax1=31+May+2024;spanmin1=01+Jan+1990;spanval1=span;template=results;type=batting" 

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    # Your scraping logic
else:
    print(f"Failed to retrieve content: {response.status_code}")

# %%
content = soup.find_all("tr",class_='data1')
print(len(content))
# Out:
# 50

# %%
for i in content:
    # print(i) 
    player = i.find_all('td')
    # print(player)
    players_info = []
    for j in player:
        if(j.text!=''):
           # print(j.text)
            players_info.append(j.text)
    break

# %%
players_info
# Out:
# ['V Kohli (IND)',
#  '2010-2024',
#  '117',
#  '109',
#  '31',
#  '4037',
#  '122*',
#  '51.75',
#  '2922',
#  '138.15',
#  '1',
#  '37',
#  '5',
#  '361',
#  '117']

# %%
# Finally scraping information from pages 1 to 78

# Initialize the final list to store players' information
final_players_list = []

# Loop through pages 1 to 78
for i in range(1, 79):
    url = f"https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page={i};spanmax2=31+May+2024;spanmin2=01+Jan+1990;spanval2=span;template=results;type=batting"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Will raise an HTTPError for bad responses
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve content from page {i}: {e}")
        continue

    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.find_all("tr", class_='data1')

    for k in content:
        player = k.find_all('td')
        players_info = [j.text.strip() for j in player if j.text.strip()]
        if players_info:
            final_players_list.append(players_info)

print(final_players_list)
# Out:
# Failed to retrieve content from page 75: HTTPSConnectionPool(host='stats.espncricinfo.com', port=443): Max retries exceeded with url: /ci/engine/stats/index.html?class=3;page=75;spanmax2=31+May+2024;spanmin2=01+Jan+1990;spanval2=span;template=results;type=batting (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000000023917410>, 'Connection to stats.espncricinfo.com timed out. (connect timeout=None)'))
# ...

# %%
field = ['name','span','matches','innings','not_outs','runs','highest_score','average','balls_faced','strike_rate','century','half_century','ducks','fours','sixes']

# %%
import csv
with open("T20I_batting_record.csv",'w') as f:
    csvwriter= csv.writer(f)
    csvwriter.writerow(field)
    csvwriter.writerows(final_players_list)
    
f.close()

# %%
df = pd.read_csv('T20I_batting_record.csv')
df.shape
# Out:
# (3822, 15)
